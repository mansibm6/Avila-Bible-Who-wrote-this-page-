# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
from IPython.display import Image

# %% [markdown]
# ## Import Classification Report for all Models
#
# 1. Linear Classifier
# 2. KNN Classifier
# 3. Random Forest Classifier
# 4. Linear SVM Classifier
# 5. Logtistic Regression Classifier
# 6. Non-Linear SVM Classifier
# 7. ELM Classifier
# 8. Deep Learning (MLP) Classifier
# 9. Non-Linear SVM (KNN feature selection)
# 10. Random Forests (KNN feature selection)
# 11. Non-Linear SVM (Bidirectional Elimination feature selection)
# 12. Random Forests (Bidirectional Elimination feature selection)
#
# Note: All the other classification report values need to be stored first by other notebooks. The stored values are accessed by this notebook.

# %%
# %store -r linear_clr_2
# %store -r knn_clr_2
# %store -r rf_clr_2
# %store -r svm_clr_2
# %store -r logr_clr_2
# %store -r nl_svm_clr_2
# %store -r elm_clr_2
# %store -r mlp_clr_2
# %store -r nl_svm_bidirectional_feature
# %store -r rf_bidirectional_feature
# %store -r nl_svm_feature
# %store -r rf_feature

# %% [markdown]
# ## Create Table of Metrics

# %%
# Create empty lists for metrics

macro_avg_precision = []
macro_avg_recall = []
macro_avg_f1score = []
accuracy = []

wt_avg_precision = []
wt_avg_recall = []
wt_avg_f1score = []

# %%
# Create list of macro average precision values for all models

macro_avg_precision.append(linear_clr_2['macro avg'].get('precision'))
macro_avg_precision.append(knn_clr_2['macro avg'].get('precision'))
macro_avg_precision.append(rf_clr_2['macro avg'].get('precision'))
macro_avg_precision.append(svm_clr_2['macro avg'].get('precision'))
macro_avg_precision.append(logr_clr_2['macro avg'].get('precision'))
macro_avg_precision.append(nl_svm_clr_2['macro avg'].get('precision'))
macro_avg_precision.append(elm_clr_2['macro avg'].get('precision'))
macro_avg_precision.append(mlp_clr_2['macro avg'].get('precision'))
macro_avg_precision.append(nl_svm_bidirectional_feature['macro avg'].get('precision'))
macro_avg_precision.append(rf_bidirectional_feature['macro avg'].get('precision'))
macro_avg_precision.append(nl_svm_feature['macro avg'].get('precision'))
macro_avg_precision.append(rf_feature['macro avg'].get('precision'))

print(macro_avg_precision)
# Out:
# [0.32871366589675144, 0.8924928924361238, 0.9928893810748519, 0.8952441379060735, 0.38997004709579347, 0.8681659476706769, 0.6663668447364244, 0.7881652775708295, 0.8332272756448226, 0.9955149635989272, 0.8298244018600013, 0.9970393579963676]

# %%
# Create list of macro average recall values for all models

macro_avg_recall.append(linear_clr_2['macro avg'].get('recall'))
macro_avg_recall.append(knn_clr_2['macro avg'].get('recall'))
macro_avg_recall.append(rf_clr_2['macro avg'].get('recall'))
macro_avg_recall.append(svm_clr_2['macro avg'].get('recall'))
macro_avg_recall.append(logr_clr_2['macro avg'].get('recall'))
macro_avg_recall.append(nl_svm_clr_2['macro avg'].get('recall'))
macro_avg_recall.append(elm_clr_2['macro avg'].get('recall'))
macro_avg_recall.append(mlp_clr_2['macro avg'].get('recall'))
macro_avg_recall.append(nl_svm_bidirectional_feature['macro avg'].get('recall'))
macro_avg_recall.append(rf_bidirectional_feature['macro avg'].get('recall'))
macro_avg_recall.append(nl_svm_feature['macro avg'].get('recall'))
macro_avg_recall.append(rf_feature['macro avg'].get('recall'))

print(macro_avg_recall)
# Out:
# [0.28246672235602915, 0.8749216846365707, 0.9655788122045315, 0.8612686231919229, 0.30844977622037845, 0.8181911756903953, 0.37453246523943223, 0.7389940854032256, 0.7739378433041674, 0.9919943976197249, 0.7787875810324715, 0.9914612451516209]

# %%
# Create list of macro average f1 values for all models

macro_avg_f1score.append(linear_clr_2['macro avg'].get('f1-score'))
macro_avg_f1score.append(knn_clr_2['macro avg'].get('f1-score'))
macro_avg_f1score.append(rf_clr_2['macro avg'].get('f1-score'))
macro_avg_f1score.append(svm_clr_2['macro avg'].get('f1-score'))
macro_avg_f1score.append(logr_clr_2['macro avg'].get('f1-score'))
macro_avg_f1score.append(nl_svm_clr_2['macro avg'].get('f1-score'))
macro_avg_f1score.append(elm_clr_2['macro avg'].get('f1-score'))
macro_avg_f1score.append(mlp_clr_2['macro avg'].get('f1-score'))
macro_avg_f1score.append(nl_svm_bidirectional_feature['macro avg'].get('f1-score'))
macro_avg_f1score.append(rf_bidirectional_feature['macro avg'].get('f1-score'))
macro_avg_f1score.append(nl_svm_feature['macro avg'].get('f1-score'))
macro_avg_f1score.append(rf_feature['macro avg'].get('f1-score'))

print(macro_avg_f1score)
# Out:
# [0.28247486007339173, 0.8812059479350798, 0.9782286512693511, 0.8769538022929879, 0.3193770515333701, 0.8389934673999332, 0.40854398137152953, 0.7526800732598503, 0.7946043829934085, 0.9937296123872138, 0.7969693941926809, 0.9941581965909743]

# %%
# Create list of macro average f1 values for all models

accuracy.append(linear_clr_2['accuracy'])
accuracy.append(knn_clr_2['accuracy'])
accuracy.append(rf_clr_2['accuracy'])
accuracy.append(svm_clr_2['accuracy'])
accuracy.append(logr_clr_2['accuracy'])
accuracy.append(nl_svm_clr_2['accuracy'])
accuracy.append(elm_clr_2['accuracy'])
accuracy.append(mlp_clr_2['accuracy'])
accuracy.append(nl_svm_bidirectional_feature['accuracy'])
accuracy.append(rf_bidirectional_feature['accuracy'])
accuracy.append(nl_svm_feature['accuracy'])
accuracy.append(rf_feature['accuracy'])

print(accuracy)
# Out:
# [0.5126976521322473, 0.877176169940904, 0.9900974285257946, 0.8439546398338923, 0.5547037214502476, 0.8335729116754512, 0.6369589522440505, 0.7779907363041048, 0.7572272799872225, 0.9956875898418783, 0.7519565564606293, 0.9966459032103497]

# %%
# Create list of weighted average precision values for all models

wt_avg_precision.append(linear_clr_2['macro avg'].get('precision'))
wt_avg_precision.append(knn_clr_2['macro avg'].get('precision'))
wt_avg_precision.append(rf_clr_2['macro avg'].get('precision'))
wt_avg_precision.append(svm_clr_2['macro avg'].get('precision'))
wt_avg_precision.append(logr_clr_2['macro avg'].get('precision'))
wt_avg_precision.append(nl_svm_clr_2['macro avg'].get('precision'))
wt_avg_precision.append(elm_clr_2['macro avg'].get('precision'))
wt_avg_precision.append(mlp_clr_2['macro avg'].get('precision'))
wt_avg_precision.append(nl_svm_bidirectional_feature['macro avg'].get('precision'))
wt_avg_precision.append(rf_bidirectional_feature['macro avg'].get('precision'))
wt_avg_precision.append(nl_svm_feature['macro avg'].get('precision'))
wt_avg_precision.append(rf_feature['macro avg'].get('precision'))

print(wt_avg_precision)
# Out:
# [0.32871366589675144, 0.8924928924361238, 0.9928893810748519, 0.8952441379060735, 0.38997004709579347, 0.8681659476706769, 0.6663668447364244, 0.7881652775708295, 0.8332272756448226, 0.9955149635989272, 0.8298244018600013, 0.9970393579963676]

# %%
# Create list of weighted average recall values for all models

wt_avg_recall.append(linear_clr_2['macro avg'].get('recall'))
wt_avg_recall.append(knn_clr_2['macro avg'].get('recall'))
wt_avg_recall.append(rf_clr_2['macro avg'].get('recall'))
wt_avg_recall.append(svm_clr_2['macro avg'].get('recall'))
wt_avg_recall.append(logr_clr_2['macro avg'].get('recall'))
wt_avg_recall.append(nl_svm_clr_2['macro avg'].get('recall'))
wt_avg_recall.append(elm_clr_2['macro avg'].get('recall'))
wt_avg_recall.append(mlp_clr_2['macro avg'].get('recall'))
wt_avg_recall.append(nl_svm_bidirectional_feature['macro avg'].get('recall'))
wt_avg_recall.append(rf_bidirectional_feature['macro avg'].get('recall'))
wt_avg_recall.append(nl_svm_feature['macro avg'].get('recall'))
wt_avg_recall.append(rf_feature['macro avg'].get('recall'))

print(wt_avg_recall)
# Out:
# [0.28246672235602915, 0.8749216846365707, 0.9655788122045315, 0.8612686231919229, 0.30844977622037845, 0.8181911756903953, 0.37453246523943223, 0.7389940854032256, 0.7739378433041674, 0.9919943976197249, 0.7787875810324715, 0.9914612451516209]

# %%
# Create list of weighted average f1 values for all models

wt_avg_f1score.append(linear_clr_2['macro avg'].get('f1-score'))
wt_avg_f1score.append(knn_clr_2['macro avg'].get('f1-score'))
wt_avg_f1score.append(rf_clr_2['macro avg'].get('f1-score'))
wt_avg_f1score.append(svm_clr_2['macro avg'].get('f1-score'))
wt_avg_f1score.append(logr_clr_2['macro avg'].get('f1-score'))
wt_avg_f1score.append(nl_svm_clr_2['macro avg'].get('f1-score'))
wt_avg_f1score.append(elm_clr_2['macro avg'].get('f1-score'))
wt_avg_f1score.append(mlp_clr_2['macro avg'].get('f1-score'))
wt_avg_f1score.append(nl_svm_bidirectional_feature['macro avg'].get('f1-score'))
wt_avg_f1score.append(rf_bidirectional_feature['macro avg'].get('f1-score'))
wt_avg_f1score.append(nl_svm_feature['macro avg'].get('f1-score'))
wt_avg_f1score.append(rf_feature['macro avg'].get('f1-score'))

print(wt_avg_f1score)
# Out:
# [0.28247486007339173, 0.8812059479350798, 0.9782286512693511, 0.8769538022929879, 0.3193770515333701, 0.8389934673999332, 0.40854398137152953, 0.7526800732598503, 0.7946043829934085, 0.9937296123872138, 0.7969693941926809, 0.9941581965909743]

# %%
Model = ['Linear', 'KNN', 'RF', 'Linear SVM', 'Logistic', 'NL SVM', 'ELM', 'MLP', 'NL SVM (bidirectional elimination)', 'RF (bidirectional elimination)', 'NL SVM (KNN feature selection)', 'RF (KNN feature selection)']

# %%
df = pd.DataFrame(list(zip(Model, macro_avg_precision, macro_avg_recall, macro_avg_f1score, wt_avg_precision, wt_avg_recall, wt_avg_f1score, accuracy)),
               columns =['Model', 'Macro Average Precision', 'Macro Average Recall', 'Macro Average F1-Score', 'Weighted Average Precision', 'Wieghted Average Recall', 'Weighted Average F1-Score', 'Accuracy'])
df = df.set_index('Model')
df
# Out:
#                                             Macro Average Precision  \
# Model
# Linear (no feature selection)                              0.328714
# KNN (no feature selection)                                 0.892493
# Random Forest (no feature selection)                       0.992889
# Linear SVM (no feature selection)                          0.895244
# Logistic (no feature selection)                            0.389970
# Non-Linear SVM (no feature selection)                      0.868166
# ELM (no feature selection)                                 0.666367
# MLP (no feature selection)                                 0.788165
# Non-Linear SVM (bidirectional elimination)                 0.833227
# Random Forests (bidirectional elimination)                 0.995515
# Non-Linear SVM (KNN feature selection)                     0.829824
# Random Forests (KNN feature selection)                     0.997039
#
#                                             Macro Average Recall  \
# Model
# Linear (no feature selection)                           0.282467
# KNN (no feature selection)                              0.874922
# Random Forest (no feature selection)                    0.965579
# Linear SVM (no feature selection)                       0.861269
# Logistic (no feature selection)                         0.308450
# Non-Linear SVM (no feature selection)                   0.818191
# ELM (no feature selection)                              0.374532
# MLP (no feature selection)                              0.738994
# Non-Linear SVM (bidirectional elimination)              0.773938
# Random Forests (bidirectional elimination)              0.991994
# Non-Linear SVM (KNN feature selection)                  0.778788
# Random Forests (KNN feature selection)                  0.991461
#
#                                             Macro Average F1-Score  \
# Model
# Linear (no feature selection)                             0.282475
# KNN (no feature selection)                                0.881206
# Random Forest (no feature selection)                      0.978229
# Linear SVM (no feature selection)                         0.876954
# Logistic (no feature selection)                           0.319377
# Non-Linear SVM (no feature selection)                     0.838993
# ELM (no feature selection)                                0.408544
# MLP (no feature selection)                                0.752680
# Non-Linear SVM (bidirectional elimination)                0.794604
# Random Forests (bidirectional elimination)                0.993730
# Non-Linear SVM (KNN feature selection)                    0.796969
# Random Forests (KNN feature selection)                    0.994158
#
#                                             Weighted Average Precision  \
# Model
# Linear (no feature selection)                                 0.328714
# KNN (no feature selection)                                    0.892493
# Random Forest (no feature selection)                          0.992889
# Linear SVM (no feature selection)                             0.895244
# Logistic (no feature selection)                               0.389970
# Non-Linear SVM (no feature selection)                         0.868166
# ELM (no feature selection)                                    0.666367
# MLP (no feature selection)                                    0.788165
# Non-Linear SVM (bidirectional elimination)                    0.833227
# Random Forests (bidirectional elimination)                    0.995515
# Non-Linear SVM (KNN feature selection)                        0.829824
# Random Forests (KNN feature selection)                        0.997039
#
#                                             Wieghted Average Recall  \
# Model
# Linear (no feature selection)                              0.282467
# KNN (no feature selection)                                 0.874922
# Random Forest (no feature selection)                       0.965579
# Linear SVM (no feature selection)                          0.861269
# Logistic (no feature selection)                            0.308450
# Non-Linear SVM (no feature selection)                      0.818191
# ELM (no feature selection)                                 0.374532
# MLP (no feature selection)                                 0.738994
# Non-Linear SVM (bidirectional elimination)                 0.773938
# Random Forests (bidirectional elimination)                 0.991994
# Non-Linear SVM (KNN feature selection)                     0.778788
# Random Forests (KNN feature selection)                     0.991461
#
#                                             Weighted Average F1-Score  \
# Model
# Linear (no feature selection)                                0.282475
# KNN (no feature selection)                                   0.881206
# Random Forest (no feature selection)                         0.978229
# Linear SVM (no feature selection)                            0.876954
# Logistic (no feature selection)                              0.319377
# Non-Linear SVM (no feature selection)                        0.838993
# ELM (no feature selection)                                   0.408544
# MLP (no feature selection)                                   0.752680
# Non-Linear SVM (bidirectional elimination)                   0.794604
# Random Forests (bidirectional elimination)                   0.993730
# Non-Linear SVM (KNN feature selection)                       0.796969
# Random Forests (KNN feature selection)                       0.994158
#
#                                             Accuracy
# Model
# Linear (no feature selection)               0.512698
# KNN (no feature selection)                  0.877176
# Random Forest (no feature selection)        0.990097
# Linear SVM (no feature selection)           0.843955
# Logistic (no feature selection)             0.554704
# Non-Linear SVM (no feature selection)       0.833573
# ELM (no feature selection)                  0.636959
# MLP (no feature selection)                  0.777991
# Non-Linear SVM (bidirectional elimination)  0.757227
# Random Forests (bidirectional elimination)  0.995688
# Non-Linear SVM (KNN feature selection)      0.751957
# Random Forests (KNN feature selection)      0.996646

# %% [markdown]
# ## Confusion Matrix

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = [60.00, 40]
plt.rcParams["figure.autolayout"] = True
plt.rcParams.update({'font.size': 20})


plt.bar(Model,accuracy)
plt.savefig('bar.png')

# %% [markdown]
# ### Linear Classifier (with all features)

# %%
Image(filename='linear_cm.png')

# %% [markdown]
# ### KNN Classifier (with all features)

# %%
Image(filename='knn_cm.png')

# %% [markdown]
# ### Random Forests Classifier (with all features)

# %%
Image(filename='rf_cm.png')

# %% [markdown]
# ### Linear SVM Classifier (with all features)

# %%
Image(filename='svm_cm.png')

# %% [markdown]
# ### Logistic Regression Classifier (with all features)

# %%
Image(filename='logr_cm.png')

# %% [markdown]
# ### Non-Linear SVM Classifier (with all features)

# %%
Image(filename='nl_svm_cm.png')

# %% [markdown]
# ### Extreme Learning Machine Classifier (with all features)

# %%
Image(filename='elm.png')

# %% [markdown]
# ### Deep Learning Classifier (Multilayered Perceptron) (with all features)

# %%
Image(filename='mlp_cm.png')

# %% [markdown]
# ### Non-Linear SVM Classifier (with bidirectional elimination feature selection)

# %%
Image(filename='nl_svm_bd.png')

# %% [markdown]
# ### Random Forests Classifier (with bidirectional elimination feature selection)

# %%
Image(filename='rf_cm_bd.png')

# %% [markdown]
# ### Non-Linear SVM Classifier (with KNN feature selection)

# %%
Image(filename='nl_svm_cm_knn.png')

# %% [markdown]
# ### Random Forests Classifier (with KNN feature selection)

# %%
Image(filename='rf_cm_knn.png')
